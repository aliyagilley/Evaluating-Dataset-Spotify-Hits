# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plot
from matplotlib import pyplot as plot
df = pd.read_csv("top10s.csv", encoding = "ISO-8859-1", engine = "python")
df
# Out:
#      Unnamed: 0                                              title  \
# 0             1                                   Hey, Soul Sister
# 1             2                               Love The Way You Lie
# 2             3                                            TiK ToK
# 3             4                                        Bad Romance
# 4             5                               Just the Way You Are
# ..          ...                                                ...
# 598         599                Find U Again (feat. Camila Cabello)
# 599         600      Cross Me (feat. Chance the Rapper & PnB Rock)
# 600         601  No Brainer (feat. Justin Bieber, Chance the Ra...
# 601         602    Nothing Breaks Like a Heart (feat. Miley Cyrus)
# 602         603                                   Kills You Slowly
#
#                artist        top genre  year  bpm  nrgy  dnce  dB  live  val  \
# 0               Train       neo mellow  2010   97    89    67  -4     8   80
# ...

# %%
#20 artists with the most hits
df["artist"].value_counts().head(20).plot.bar()
# Out:
# <AxesSubplot:>

# %%
#want to know the top 10 popular artists from 2010-2019 from best to least best. Let's see if I can figure out how...
#this will be  different than seeing what artists have the "most" hits; this will be looking at the most popular hits.
#finding the average popularity of each artist and putting in ascending order
df_avg_pop_artist = df[['artist','pop']].groupby('artist').mean().astype(int).reset_index().sort_values(by='pop', ascending = False, inplace = False).head(10)

sns.catplot(x = 'artist', y = 'pop', data = df_avg_pop_artist, kind ='bar', aspect = 3)
plot.xlabel('Artist')
plot.ylabel('Popularity')
plot.title('Top 10 Popular Artists')
# Out:
# Text(0.5, 1.0, 'Top 10 Popular Artists')

# %%
#thought it would be interesting to see the least popular artists from this decade!  Let's see if any of your favorites (or least favorites) are in here.
df_avg_least_pop_artist = df[['artist','pop']].groupby('artist').mean().astype(int).reset_index().sort_values(by='pop', ascending = False, inplace = False).tail(10)

sns.catplot(x = 'artist',y = 'pop', data = df_avg_least_pop_artist, kind ='bar', aspect = 3)
plot.xlabel('Artist')
plot.ylabel('Popularity')
plot.title('Top 10 Least Popular Artists')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22276/2916908452.py in <module>
#       5 plot.xlabel('Artist')
#       6 plot.ylabel('Popularity')
# ----> 7 plot.title('Top 10 Least Popular Artists')
#
# TypeError: 'str' object is not callable

# %%
#want to know the top 10 popular songs from 2010-2019. Let's see if I can figure out how...

df_avg_pop_song = df[['title','pop']].groupby('title').mean().astype(int).reset_index().sort_values(by='pop', ascending = False, inplace = False).head(10)
#a friend that is much better at python told me about catplot, and it's super useful! Helps me to visualize the data more.
sns.catplot(x = 'title',y = 'pop', data = df_avg_pop_song, kind ='bar', aspect = 8.5)
plot.xticks(fontsize = 15)
plot.xlabel('Song Title', fontsize = 15)
plot.ylabel('Popularity', fontsize = 15)
plot.title('Top 10 Popular Songs')
# Out:
# Text(0.5, 1.0, 'Top 10 Popular Songs')

# %%
#evaluation of one of my favorite artists
the_weeknd = df[df["artist"] == "The Weeknd"]
print(the_weeknd)
# Out:
#      Unnamed: 0                                              title  \
# 270         271                                          The Hills
# 278         279  Earned It (Fifty Shades Of Grey) - From The "F...
# 363         364                                          The Hills
# 445         446                                            Starboy
# 449         450                                   I Feel It Coming
#
#          artist                  top genre  year  bpm  nrgy  dnce  dB  live  \
# 270  The Weeknd  canadian contemporary r&b  2015  113    56    58  -7    14
# 278  The Weeknd  canadian contemporary r&b  2015  120    38    66  -6    10
# 363  The Weeknd  canadian contemporary r&b  2016  113    56    58  -7    14
# 445  The Weeknd  canadian contemporary r&b  2017  186    59    68  -7    14
# 449  The Weeknd  canadian contemporary r&b  2017   93    82    77  -6     7
#
#      val  dur  acous  spch  pop
# 270   14  242      7     5   84
# 278   44  252     39     3   79
# ...

# %%
weeknd_year = the_weeknd["artist"].value_counts()
print(weeknd_year)
# Out:
# The Weeknd    5
# Name: artist, dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0         year         bpm        nrgy        dnce  \
# count  603.000000   603.000000  603.000000  603.000000  603.000000
# mean   302.000000  2014.592040  118.545605   70.504146   64.379768
# std    174.215384     2.607057   24.795358   16.310664   13.378718
# min      1.000000  2010.000000    0.000000    0.000000    0.000000
# 25%    151.500000  2013.000000  100.000000   61.000000   57.000000
# 50%    302.000000  2015.000000  120.000000   74.000000   66.000000
# 75%    452.500000  2017.000000  129.000000   82.000000   73.000000
# max    603.000000  2019.000000  206.000000   98.000000   97.000000
#
#                dB        live         val         dur       acous        spch  \
# count  603.000000  603.000000  603.000000  603.000000  603.000000  603.000000
# mean    -5.578773   17.774461   52.225539  224.674959   14.326700    8.358209
# std      2.798020   13.102543   22.513020   34.130059   20.766165    7.483162
# ...

# %%
#want to make a scatter plot of some of the comparing columns.  Let's try loudness (dB) and energy (nrgy)

#df.plot.scatter(x = "nrgy", y = "dB")
sns.regplot(x = df["nrgy"], y = df["dB"])
plot.title = "Comparison of Loudness (dB) and Energy (nrgy)"
plot.xlabel("Energy")
plot.ylabel("Loudness")
# Out:
# Text(0, 0.5, 'Loudness')

# %%
#want to make a scatter plot of some of the comparing columns.  Let's try Beats Per Minute (bpm) and Danceability (dnce)
#df.plot.scatter(x = "bpm", y = "dnce")
sns.regplot(x = df["bpm"], y = df["dnce"])
plot.title = "Comparison of Beats Per Minute (bpm) and Danceability (dnce)"
plot.xlabel("Beats Per Minute")
plot.ylabel("Danceability")
# Out:
# Text(0, 0.5, 'Danceability')

# %%
# Run the simulation for liveness 10000 times
#need to create a function to simulate average first
def simulate(column, n):
    return df[column].sample(n).mean()
#now to simulate
data = []
for i in range(1000):
    live100 = simulate("live", 100)
    d = {"live100" : live100}
    data.append(d)

df_live_100 = pd.DataFrame(data)

#create hist
df_live_100.hist()
# Out:
# array([[<AxesSubplot:title={'center':'live100'}>]], dtype=object)

# %%
#what are the most common genres from the decade?
print(df["top genre"].value_counts().head(10))
print(df["top genre"].value_counts().head(10).plot.bar())
# Out:
# dance pop                    327
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    13
# british soul                  11
# big room                      10
# canadian contemporary r&b      9
# neo mellow                     9
# Name: top genre, dtype: int64
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
# let's find a more fun way to look at what we just did. How about a pie chart?
#looking to see what genres were the most popular during this time period. Admittedly, Google helped out with this a little, but I think these are good to know for the future in data!
#value_counts() is super useful. It made my code run a lot more efficiently (check out the second code I tried out first)
# needed to take what we have above, plot as a pie chart, and change to percentages 
df['top genre'].value_counts().head(20).plot.pie(figsize = (10,10), autopct='%1.0f%%')

#df.groupby("top genre")["pop"].count().plot.pie(figsize = (20,20), subplots = True, autopct = "%1.0f%%")
# Out:
# <AxesSubplot:ylabel='top genre'>
